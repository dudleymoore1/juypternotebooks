# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import CoolProp

# %% [markdown]
# # Dilute Phase Transport
#
# ## This section presents the empirical equations needed to evaluate mass transport in a dilute phase transport system. This equations were gathered from :
# ### https://conservancy.umn.edu/bitstream/handle/11299/160150/Kawale_umn_0130M_14253.pdf?sequence=1&isAllowed=y

# %% [markdown]
# (4.1)    $\frac{U_{ch}}{\varepsilon_{ch}} = U_{T} - \frac{G}{\rho_{p}(1-\varepsilon_{ch})}$

# %% [markdown]
# (4.2)    $U_{ch} = \varepsilon_{ch} (U_{T} + \frac{2250D(\varepsilon_{ch}^{-4.7} -1)}{\rho_{f}^{0.77}}^{\frac{1}{2}})$

# %% [markdown]
# (4.3)    $U_{T} = \frac{2r_{p}^{2}(\rho_{p}-\rho_{f})g}{18\mu_{f}}$

# %%
from IPython.display import IFrame
IFrame("diluteTransport.pdf",width = 600,height = 300)
