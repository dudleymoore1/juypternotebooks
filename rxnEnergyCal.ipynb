# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import CoolProp

# %% [markdown]
# # Dilute Phase Transport
#
# ## This section presents the empirical equations needed to evaluate mass transport in a dilute phase transport system.

# %%
from IPython.display import IFrame
IFrame("diluteTransport.pdf",width = 1200,height = 1200)
# Out:
#         <iframe
#             width="1200"
#             height="1200"
#             src="diluteTransport.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# (4.1)    $\frac{U_{ch}}{\varepsilon_{ch}} = U_{T} - \frac{G}{\rho_{p}(1-\varepsilon_{ch})}$

# %% [markdown]
# (4.2)    $U_{ch} = \varepsilon_{ch} (U_{T} + \frac{2250D(\varepsilon_{ch}^{-4.7} -1)}{\rho_{f}^{0.77}}^{\frac{1}{2}})$

# %% [markdown]
# (4.3)    $U_{T} = \frac{2r_{p}^{2}(\rho_{p}-\rho_{f})g}{18\mu_{f}}$
